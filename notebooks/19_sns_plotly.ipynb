# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(sum(map(ord, "aesthetics")))

def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

sinplot()

# %%
import seaborn as sns
# в seaborn забито несколько стилей
sns.set_style('whitegrid')

# %%
sinplot()

# %%
with sns.axes_style('darkgrid'):
    sinplot()

# %%
sinplot()

# %%
sns.set_style("darkgrid", {'axes.facecolor': '.9'})
sinplot()

# %%
# и он может подгрузить популярные массивы данных
# по названиям из этого репозитория https://github.com/mwaskom/seaborn-data

titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## 1. Постройте гистограмму возраста пассажиров
# ### постройте по нему одномерное распределение
#
# гуглите функцию **distplot**

# %%
sns.distplot(titanic["age"])
# Out:
# C:\Users\almuravtsev\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
fig = sns.distplot(titanic["age"], kde=False)
# Out:
# C:\Users\almuravtsev\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 2. Постройте парную гистограмму "возраст-плата"
#
# гуглите функцию **jointplot**

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %% [markdown]
# ## 3. Постройте ящики с усами со стоимостью для каждого класса пассажиров
#
# гуглите функцию **boxplot**

# %%
ax = sns.boxplot(x='class',y='fare',data=titanic, palette='rainbow')
ax.set_ylim([0, 250])
# Out:
# (0.0, 250.0)

# %%
print(sns.__version__)
# Out:
# 0.11.2

# %%
# причём это всё ещё объект matplotlib!
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ## 4. Постройте гистограмму по категариальной переменной - по полу
#
# гуглите функцию **countplot**

# %%
sns.countplot(x='sex',data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## 5. Постройте корреляционную функцию между признаками
#
# гуглите функцию **heatmap** и **corr**

# %%
fig = sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
sns.pairplot(titanic[["age", "fare", "pclass"]])

# %%
import plotly.tools as tls
import plotly.offline as py

# %%
plotly_fig = tls.mpl_to_plotly(fig)
# plotly_fig = go.Figure(plotly_fig) 
# plotly_fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\almuravtsev\Documents\PythonIntroCourse2020\notebooks\19_sns_plotly.ipynb Cell 26' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/almuravtsev/Documents/PythonIntroCourse2020/notebooks/19_sns_plotly.ipynb#ch0000020?line=0'>1</a> plotly_fig = tls.mpl_to_plotly(fig)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\tools.py:112, in mpl_to_plotly(fig, resize, strip_style, verbose)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/tools.py?line=109'>110</a> if matplotlylib:
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/tools.py?line=110'>111</a>     renderer = matplotlylib.PlotlyRenderer()
# --> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/tools.py?line=111'>112</a>     matplotlylib.Exporter(renderer).run(fig)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/tools.py?line=112'>113</a>     if resize:
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/tools.py?line=113'>114</a>         renderer.resize()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\matplotlylib\mplexporter\exporter.py:46, in Exporter.run(self, fig)
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=35'>36</a> """
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=36'>37</a> Run the exporter on the given figure
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=37'>38</a>
#    (...)
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=41'>42</a>     The figure to export
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=42'>43</a> """
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=43'>44</a> # Calling savefig executes the draw() command, putting elements
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=44'>45</a> # in the correct place.
# ---> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=45'>46</a> if fig.canvas is None:
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=46'>47</a>     canvas = FigureCanvasAgg(fig)
#      <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/plotly/matplotlylib/mplexporter/exporter.py?line=47'>48</a> fig.savefig(io.BytesIO(), format="png", dpi=fig.dpi)
#
# AttributeError: 'AxesSubplot' object has no attribute 'canvas'
